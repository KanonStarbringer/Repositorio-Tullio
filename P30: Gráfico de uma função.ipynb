# %%
#P30: Gráfico de uma função
import pandas as pd

# %%
df = pd.DataFrame({"x": list(range(1,11))})
df["y"] = (df.x*2) + 3
lines = df.plot.line(x="x", y="y", legend=False)

# %%
print(df)
# Out:
#     x   y
# 0   1   5
# 1   2   7
# 2   3   9
# 3   4  11
# 4   5  13
# 5   6  15
# 6   7  17
# 7   8  19
# 8   9  21
# 9  10  23
