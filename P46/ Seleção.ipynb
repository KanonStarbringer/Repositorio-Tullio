# %%
#P46: Seleção
import pandas as pd

# %%
#1 Importa as bases de dados
flags = pd.read_csv('/Users/TullioPires/flags.csv')

# %%
#2 Seleciona somente as linhas dos países da oceania
v = (flags['landmass']==6)
flags_oceania = flags[v] #poderia ficar, também flags_oceania = flags[flags['landmass']==6]

# %%
#países que não são de oceania
nao_oceania = flags[flags['landmass']!=6]

# %%
print(nao_oceania)
# Out:
#             name  landmass  zone  area  population  language  religion  bars  \
# 0    Afghanistan         5     1   648          16        10         2     0
# 1        Albania         3     1    29           3         6         6     0
# 2        Algeria         4     1  2388          20         8         2     2
# 4        Andorra         3     1     0           0         6         0     3
# 5         Angola         4     2  1247           7        10         5     0
# ..           ...       ...   ...   ...         ...       ...       ...   ...
# 188      Vietnam         5     1   333          60        10         6     0
# 190   Yugoslavia         3     1   256          22         6         6     0
# 191        Zaire         4     2   905          28        10         5     0
# 192       Zambia         4     2   753           6        10         5     3
# 193     Zimbabwe         4     2   391           8        10         5     0
#
# ...

# %%
#países com no máximo duas cores na bandeira
duas_cores = flags[flags['colours'] <=2]

# %%
print(duas_cores)
# Out:
#                 name  landmass  zone   area  population  language  religion  \
# 8          Argentina         2     3   2777          28         2         0
# 11           Austria         3     1     84           8         4         0
# 13           Bahrain         5     1      1           0         8         2
# 14        Bangladesh         5     1    143          90         6         2
# 18             Benin         4     1    113           3         3         5
# 31            Canada         1     4   9976          24         1         1
# 37             China         5     1   9561        1008         7         6
# 39   Comorro-Islands         4     2      2           0         3         2
# 46           Denmark         3     1     43           5         6         1
# 52       El-Salvador         1     4     21           5         2         0
# 58           Finland         3     1    337           5         9         1
# ...

# %%
#imprime os países da oceania
print(flags_oceania)
# Out:
#                  name  landmass  zone  area  population  language  religion  \
# 3      American-Samoa         6     3     0           0         1         1
# 10          Australia         6     2  7690          15         1         1
# 41       Cook-Islands         6     3     0           0         1         1
# 57               Fiji         6     2    18           1         1         1
# 61   French-Polynesia         6     3     4           0         3         0
# 71               Guam         6     1     0           0         1         1
# 82          Indonesia         6     2  1904         157        10         2
# 94           Kiribati         6     1     0           0         1         1
# 109          Marianas         6     1     0           0        10         1
# 113        Micronesia         6     1     1           0        10         1
# 119             Nauru         6     2     0           0        10         1
# ...
